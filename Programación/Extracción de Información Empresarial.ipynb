# %% [markdown]
# **Nota:** Datos utilizados en los cálculos. Algunas tablas se exportaron a Tableau para mejorar la presentación de las cifras.
# Fuente: Extracciones a medida de cálculos realizados sobre la base de datos longitudinal construida a partir del RUES y convenio de investigación con el PILA.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"]=[18.0,10.0]
plt.style.use('ggplot')

# %%
puras = pd.read_csv('Puras.csv', delimiter=';')

# %%
puras
# Out:
#     Año  Número de empresas  Empresas creadas
# 0  2011             1233944            229125
# 1  2012             1297686            271561
# 2  2013             1342921            266693
# 3  2014             1431133            292124
# 4  2015             1470884            247126
# 5  2016             1482375            264150
# 6  2017             1563832            294880
# 7  2018             1619041            303027

# %%
puras.describe(include='all')
# Out:
#               Año  Número de empresas  Empresas creadas
# count     8.00000        8.000000e+00          8.000000
# mean   2014.50000        1.430227e+06     271085.750000
# std       2.44949        1.317957e+05      25160.679787
# min    2011.00000        1.233944e+06     229125.000000
# 25%    2012.75000        1.331612e+06     259894.000000
# 50%    2014.50000        1.451008e+06     269127.000000
# 75%    2016.25000        1.502739e+06     292813.000000
# max    2018.00000        1.619041e+06     303027.000000

# %%
puras['Empresas creadas']
# Out:
# 0    229125
# 1    271561
# 2    266693
# 3    292124
# 4    247126
# 5    264150
# 6    294880
# 7    303027
# Name: Empresas creadas, dtype: int64

# %%
puras['Empresas creadas'].to_frame()
# Out:
#    Empresas creadas
# 0            229125
# 1            271561
# 2            266693
# 3            292124
# 4            247126
# 5            264150
# 6            294880
# 7            303027

# %%
puras.loc[:,["Año","Empresas creadas"]]
# Out:
#     Año  Empresas creadas
# 0  2011            229125
# 1  2012            271561
# 2  2013            266693
# 3  2014            292124
# 4  2015            247126
# 5  2016            264150
# 6  2017            294880
# 7  2018            303027

# %%
figura1=puras.plot("Año", "Empresas creadas", kind="bar", title="Número de empresas creadas 2011-2018", colormap="tab20c");
plt.savefig('figure1.png')

# %%
superv_micro = pd.read_csv('Supervivencia Micro.csv', delimiter=';')

# %%
super=superv_micro.drop(columns='Unnamed: 5')
super
# Out:
#      Año  Cohorte Microempresas (2011)  Cohorte Microempresas (2012)  \
# 0  Año 0                           100                           100
# 1  Año 1                            64                            63
# 2  Año 2                            52                            54
# 3  Año 3                            45                            47
# 4  Año 4                            39                            41
# 5  Año 5                            29                            34
#
#    Cohorte (2011)  Cohorte (2012)  Unnamed: 6  Unnamed: 7
# 0             100             100         NaN         NaN
# 1              63              64         NaN         NaN
# 2              54              54         NaN         NaN
# 3              47              48         NaN         NaN
# 4              41              41         NaN         NaN
# 5              34              35         NaN         NaN

# %%
super1=super.drop(columns='Unnamed: 6')
super1
# Out:
#      Año  Cohorte Microempresas (2011)  Cohorte Microempresas (2012)  \
# 0  Año 0                           100                           100
# 1  Año 1                            64                            63
# 2  Año 2                            52                            54
# 3  Año 3                            45                            47
# 4  Año 4                            39                            41
# 5  Año 5                            29                            34
#
#    Cohorte (2011)  Cohorte (2012)  Unnamed: 7
# 0             100             100         NaN
# 1              63              64         NaN
# 2              54              54         NaN
# 3              47              48         NaN
# 4              41              41         NaN
# 5              34              35         NaN

# %%
super2=super1.drop(columns='Unnamed: 7')
super2
# Out:
#      Año  Cohorte Microempresas (2011)  Cohorte Microempresas (2012)  \
# 0  Año 0                           100                           100
# 1  Año 1                            64                            63
# 2  Año 2                            52                            54
# 3  Año 3                            45                            47
# 4  Año 4                            39                            41
# 5  Año 5                            29                            34
#
#    Cohorte (2011)  Cohorte (2012)
# 0             100             100
# 1              63              64
# 2              54              54
# 3              47              48
# 4              41              41
# 5              34              35

# %%
superv_empresarial=super2

# %%
superv_empresarial.describe(include='all')
# Out:
#           Año  Cohorte Microempresas (2011)  Cohorte Microempresas (2012)  \
# count       6                      6.000000                      6.000000
# unique      6                           NaN                           NaN
# top     Año 5                           NaN                           NaN
# freq        1                           NaN                           NaN
# mean      NaN                     54.833333                     56.500000
# std       NaN                     25.087181                     23.569047
# min       NaN                     29.000000                     34.000000
# 25%       NaN                     40.500000                     42.500000
# 50%       NaN                     48.500000                     50.500000
# 75%       NaN                     61.000000                     60.750000
# max       NaN                    100.000000                    100.000000
#
#         Cohorte (2011)  Cohorte (2012)
# count         6.000000        6.000000
# ...

# %%
superv_empresarial
# Out:
#      Año  Cohorte Microempresas (2011)  Cohorte Microempresas (2012)  \
# 0  Año 0                           100                           100
# 1  Año 1                            64                            63
# 2  Año 2                            52                            54
# 3  Año 3                            45                            47
# 4  Año 4                            39                            41
# 5  Año 5                            29                            34
#
#    Cohorte (2011)  Cohorte (2012)
# 0             100             100
# 1              63              64
# 2              54              54
# 3              47              48
# 4              41              41
# 5              34              35

# %%
figura2=superv_empresarial.plot("Año", "Cohorte (2011)", kind="line", colormap="tab20");
plt.savefig('figure2.png')

# %%
rama = pd.read_csv('Ramas Actividad.csv', delimiter=';') 
rama
# Out:
#                                                  Rama  \
# 0                                         Agricultura
# 1                                              Minas
# 2                                           Industria
# 3                 Suministro electricidad, gas, vapor
# 4                   Distribución de agua, saneamiento
# 5                                        Construcción
# 6       Comercio, reparación vehículos y motocicletas
# 7                         Transporte y almacenamiento
# 8                   Alojamiento y servicios de comida
# 9                        Información y comunicaciones
# 10                  Actividades financieras y seguros
# 11                          Actividades inmobiliarias
# 12  Actividades profesionales, científicas y técnicas
# 13           Actividades de servicios adm. y de apoyo
# 14                                    No identificada
# 15                                    No identificada
# ...

# %%
figura3=rama.plot("Rama", "Empresas creadas promedio", kind="bar", colormap="tab20b");
plt.savefig('figure3.png')

# %%
depto = pd.read_csv('Departamento Puras.csv', delimiter=';') 
depto
# Out:
#        Departamento  Empresas creadas promedio
# 0          AMAZONAS                        451
# 1         ANTIOQUIA                      31978
# 2            ARAUCA                       1675
# 3         ATLANTICO                      13473
# 4            BOGOTA                      64428
# 5           BOLIVAR                       8215
# 6            BOYACA                       7796
# 7            CALDAS                       5190
# 8           CAQUETA                       2032
# 9          CASANARE                       3724
# 10            CAUCA                       4095
# 11            CESAR                       5050
# 12            CHOCO                       1562
# 13          CORDOBA                       3878
# 14     CUNDINAMARCA                      14863
# 15          GUAINIA                        174
# 16         GUAVIARE                        505
# 17            HUILA                       7049
# 18       LA GUAJIRA                       2672
# ...

# %%
figura4=depto.plot("Departamento", "Empresas creadas promedio", kind="bar", colormap="Pastel2");
plt.savefig('figure4.png')
